# %%
from src.data_generation.generate_marketplace_data import generate_marketplace_data

# %% [markdown]
# Purpose:
#
# 	•	run the generator
# 	•	explain the simulation design
# 	•	show the generated tables
#
# What it includes:
#
# 	•	description of the synthetic marketplace
# 	•	loading the generated data
# 	•	quick preview tables
#
#
# Example sections:
#
# 	1. Simulation Overview
# 	2. Generate Marketplace Data
# 	3. Inspect Generated Tables
# 	4. Validate Dataset Size
